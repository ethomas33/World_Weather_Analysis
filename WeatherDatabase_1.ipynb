# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime
from citipy import citipy
import requests
from config1 import weather_api_key

# %%
# Create a set of random lat and long combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=500)
longs = np.random.uniform(low=-180.000, high=180.000, size=500)
lat_longs = zip(lats, longs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_longs)

# %%
# create a list for holding the cities.
cities = []
#identify the nearest city for each lat long combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    #if the city is unique then we will at it to the cities list.
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 261

# %%
# Starting URL for Weather Map API Call.(from module)
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create an empty list to hold weather data
city_data = []
#print the beginning of the loging.
print("Beginning Data Retrieval    ")
print("----------------------------")

#create counter
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | guerrero negro
# Processing Record 2 of Set 1 | zhuzhou
# Processing Record 3 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 1 | hilo
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | aanekoski
# Processing Record 10 of Set 1 | tautira
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | lagoa
# Processing Record 19 of Set 1 | severo-kurilsk
# Processing Record 20 of Set 1 | cherskiy
# Processing Record 21 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | cayhagan
# Processing Record 27 of Set 1 | hobart
# Processing Record 28 of Set 1 | richards bay
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | merauke
# Processing Record 35 of Set 1 | hofn
# Processing Record 36 of Set 1 | qui nhon
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | zhicheng
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | mbaiki
# Processing Record 42 of Set 1 | sovetskiy
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | idaho falls
# Processing Record 45 of Set 1 | port augusta
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | kavieng
# Processing Record 48 of Set 1 | tiksi
# Processing Record 49 of Set 1 | batagay
# Processing Record 50 of Set 1 | sungaipenuh
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | waverly
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | cidreira
# Processing Record 5 of Set 2 | nikolskoye
# Processing Record 6 of Set 2 | comodoro rivadavia
# Processing Record 7 of Set 2 | husavik
# Processing Record 8 of Set 2 | broome
# Processing Record 9 of Set 2 | santa maria da vitoria
# Processing Record 10 of Set 2 | goderich
# Processing Record 11 of Set 2 | kuusamo
# Processing Record 12 of Set 2 | gumdag
# Processing Record 13 of Set 2 | spasskoye
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | clyde river
# Processing Record 16 of Set 2 | skjaerhollen
# City not found. Skipping...
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | general roca
# Processing Record 19 of Set 2 | lorengau
# Processing Record 20 of Set 2 | fuxin
# Processing Record 21 of Set 2 | iqaluit
# Processing Record 22 of Set 2 | axim
# Processing Record 23 of Set 2 | grafton
# Processing Record 24 of Set 2 | hambantota
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | touros
# Processing Record 28 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 2 | fortuna
# Processing Record 30 of Set 2 | maningrida
# Processing Record 31 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 2 | saint george
# Processing Record 33 of Set 2 | college
# Processing Record 34 of Set 2 | labis
# Processing Record 35 of Set 2 | san lazaro
# Processing Record 36 of Set 2 | dingle
# Processing Record 37 of Set 2 | san juan
# Processing Record 38 of Set 2 | vigrestad
# Processing Record 39 of Set 2 | kenai
# Processing Record 40 of Set 2 | mae sai
# Processing Record 41 of Set 2 | kostino
# Processing Record 42 of Set 2 | codrington
# Processing Record 43 of Set 2 | sao filipe
# Processing Record 44 of Set 2 | surgut
# Processing Record 45 of Set 2 | punta arenas
# Processing Record 46 of Set 2 | raton
# Processing Record 47 of Set 2 | aykhal
# Processing Record 48 of Set 2 | narsaq
# Processing Record 49 of Set 2 | coetupo
# City not found. Skipping...
# Processing Record 50 of Set 2 | poya
