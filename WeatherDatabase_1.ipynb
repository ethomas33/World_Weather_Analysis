# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime
from citipy import citipy
import requests
from config1 import weather_api_key

# %%
# Create a set of random lat and long combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
longs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_longs = zip(lats, longs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_longs)

# %%
# create a list for holding the cities.
cities = []
#identify the nearest city for each lat long combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    #if the city is unique then we will at it to the cities list.
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 790

# %%
# Starting URL for Weather Map API Call.(from module)
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create an empty list to hold weather data
city_data = []
#print the beginning of the loging.
print("Beginning Data Retrieval    ")
print("----------------------------")

#create counter
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | cayenne
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | lebu
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | tasiilaq
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | ponta do sol
# Processing Record 9 of Set 1 | west plains
# Processing Record 10 of Set 1 | geraldton
# Processing Record 11 of Set 1 | yacuiba
# Processing Record 12 of Set 1 | clyde river
# Processing Record 13 of Set 1 | mayor pablo lagerenza
# Processing Record 14 of Set 1 | salta
# Processing Record 15 of Set 1 | kikwit
# Processing Record 16 of Set 1 | bone
# Processing Record 17 of Set 1 | mandera
# Processing Record 18 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 19 of Set 1 | new norfolk
# Processing Record 20 of Set 1 | luderitz
# Processing Record 21 of Set 1 | constitucion
# Processing Record 22 of Set 1 | port-de-bouc
# Processing Record 23 of Set 1 | kaifeng
# Processing Record 24 of Set 1 | iqaluit
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | fomboni
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | saint-louis
# Processing Record 31 of Set 1 | saskylakh
# Processing Record 32 of Set 1 | verkhnevilyuysk
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | simao
# Processing Record 35 of Set 1 | shingu
# Processing Record 36 of Set 1 | tsiroanomandidy
# Processing Record 37 of Set 1 | high rock
# Processing Record 38 of Set 1 | mogadishu
# Processing Record 39 of Set 1 | vaini
# Processing Record 40 of Set 1 | pangnirtung
# Processing Record 41 of Set 1 | urumqi
# Processing Record 42 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 43 of Set 1 | brooks
# Processing Record 44 of Set 1 | narsaq
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | haines junction
# Processing Record 47 of Set 1 | cap malheureux
# Processing Record 48 of Set 1 | upernavik
# Processing Record 49 of Set 1 | solnechnyy
# Processing Record 50 of Set 1 | san cristobal
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | sao filipe
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | zaltan
# Processing Record 5 of Set 2 | norman wells
# Processing Record 6 of Set 2 | goroka
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | luanda
# Processing Record 10 of Set 2 | mataura
# Processing Record 11 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 2 | hervey bay
# Processing Record 13 of Set 2 | karratha
# Processing Record 14 of Set 2 | arlit
# Processing Record 15 of Set 2 | katsuura
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | jiehu
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | dayong
# Processing Record 20 of Set 2 | ostrovnoy
# Processing Record 21 of Set 2 | qaanaaq
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | souillac
# Processing Record 24 of Set 2 | klaksvik
# Processing Record 25 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 26 of Set 2 | ambon
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | okhotsk
# Processing Record 30 of Set 2 | nanortalik
# Processing Record 31 of Set 2 | gigmoto
# Processing Record 32 of Set 2 | nome
# Processing Record 33 of Set 2 | tacoronte
# Processing Record 34 of Set 2 | saint george
# Processing Record 35 of Set 2 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 2 | victoria
# Processing Record 37 of Set 2 | lompoc
# Processing Record 38 of Set 2 | bandar-e lengeh
# Processing Record 39 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 2 | faya
# Processing Record 41 of Set 2 | deputatskiy
# Processing Record 42 of Set 2 | mugumu
# Processing Record 43 of Set 2 | vasudevanallur
# Processing Record 44 of Set 2 | chamba
# Processing Record 45 of Set 2 | dankov
# Processing Record 46 of Set 2 | sumbe
# Processing Record 47 of Set 2 | georgetown
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | ryabovo
# Processing Record 50 of Set 2 | chegdomyn
# Processing Record 1 of Set 3 | storebo
# Processing Record 2 of Set 3 | harboore
# Processing Record 3 of Set 3 | newport
# Processing Record 4 of Set 3 | vila
# Processing Record 5 of Set 3 | richards bay
# Processing Record 6 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 7 of Set 3 | provideniya
# Processing Record 8 of Set 3 | preeceville
# Processing Record 9 of Set 3 | neiafu
# Processing Record 10 of Set 3 | basco
# Processing Record 11 of Set 3 | sundsvall
# Processing Record 12 of Set 3 | sitka
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 3 | trinidad
# Processing Record 16 of Set 3 | nikolskoye
# Processing Record 17 of Set 3 | tuktoyaktuk
# Processing Record 18 of Set 3 | trelew
# Processing Record 19 of Set 3 | egvekinot
# Processing Record 20 of Set 3 | svarstad
# Processing Record 21 of Set 3 | alice springs
# Processing Record 22 of Set 3 | chontalpa
# Processing Record 23 of Set 3 | meulaboh
# Processing Record 24 of Set 3 | chokurdakh
# Processing Record 25 of Set 3 | prince rupert
# Processing Record 26 of Set 3 | hammerum
# Processing Record 27 of Set 3 | portales
# Processing Record 28 of Set 3 | cherskiy
# Processing Record 29 of Set 3 | ambilobe
# Processing Record 30 of Set 3 | dikson
# Processing Record 31 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 3 | liverpool
# Processing Record 34 of Set 3 | ribeira grande
# Processing Record 35 of Set 3 | alexander city
# Processing Record 36 of Set 3 | lewisporte
# Processing Record 37 of Set 3 | abbotsford
# Processing Record 38 of Set 3 | half moon bay
# Processing Record 39 of Set 3 | puerto ayora
# Processing Record 40 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 3 | saint-philippe
# Processing Record 42 of Set 3 | maple creek
# Processing Record 43 of Set 3 | pringsewu
# Processing Record 44 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 3 | pevek
# Processing Record 46 of Set 3 | chaman
# Processing Record 47 of Set 3 | pilibanga
# Processing Record 48 of Set 3 | namibe
# Processing Record 49 of Set 3 | nanakuli
# Processing Record 50 of Set 3 | aksha
# Processing Record 1 of Set 4 | torbay
# Processing Record 2 of Set 4 | juegang
# Processing Record 3 of Set 4 | tacna
# Processing Record 4 of Set 4 | corrente
# Processing Record 5 of Set 4 | langenburg
# Processing Record 6 of Set 4 | barrow
# Processing Record 7 of Set 4 | esperance
# Processing Record 8 of Set 4 | kaitangata
# Processing Record 9 of Set 4 | rio branco
# Processing Record 10 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 4 | santa cruz de la palma
# Processing Record 12 of Set 4 | carnarvon
# Processing Record 13 of Set 4 | port blair
# Processing Record 14 of Set 4 | bambous virieux
# Processing Record 15 of Set 4 | konstantinovo
# Processing Record 16 of Set 4 | cabo san lucas
# Processing Record 17 of Set 4 | port macquarie
# Processing Record 18 of Set 4 | sept-iles
# Processing Record 19 of Set 4 | khatanga
# Processing Record 20 of Set 4 | aswan
# Processing Record 21 of Set 4 | kimbe
# Processing Record 22 of Set 4 | kapaa
# Processing Record 23 of Set 4 | monrovia
# Processing Record 24 of Set 4 | kenai
# Processing Record 25 of Set 4 | severo-kurilsk
# Processing Record 26 of Set 4 | poum
# Processing Record 27 of Set 4 | hami
# Processing Record 28 of Set 4 | butaritari
# Processing Record 29 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 4 | birao
# Processing Record 31 of Set 4 | coahuayana
# Processing Record 32 of Set 4 | hengshui
# Processing Record 33 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 4 | krasnohrad
# Processing Record 35 of Set 4 | fortuna
# Processing Record 36 of Set 4 | hithadhoo
# Processing Record 37 of Set 4 | mount isa
# Processing Record 38 of Set 4 | slave lake
# Processing Record 39 of Set 4 | vao
# Processing Record 40 of Set 4 | beringovskiy
# Processing Record 41 of Set 4 | airai
# Processing Record 42 of Set 4 | san quintin
# Processing Record 43 of Set 4 | avarua
# Processing Record 44 of Set 4 | yerbogachen
# Processing Record 45 of Set 4 | laguna
# Processing Record 46 of Set 4 | kinsale
# Processing Record 47 of Set 4 | miyako
# Processing Record 48 of Set 4 | general roca
# Processing Record 49 of Set 4 | balassagyarmat
# Processing Record 50 of Set 4 | leningradskiy
# Processing Record 1 of Set 5 | tura
# Processing Record 2 of Set 5 | guerrero negro
# Processing Record 3 of Set 5 | zhezkazgan
# Processing Record 4 of Set 5 | lebedinyy
# Processing Record 5 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 5 | mahebourg
# Processing Record 7 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 5 | noshiro
# Processing Record 9 of Set 5 | santa rosa
# Processing Record 10 of Set 5 | east london
# Processing Record 11 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 5 | stornoway
# Processing Record 13 of Set 5 | jhelum
# Processing Record 14 of Set 5 | kirakira
# Processing Record 15 of Set 5 | uppsala
# Processing Record 16 of Set 5 | sur
# Processing Record 17 of Set 5 | cockburn town
# Processing Record 18 of Set 5 | guanica
# Processing Record 19 of Set 5 | tuatapere
# Processing Record 20 of Set 5 | cervo
# Processing Record 21 of Set 5 | santa rosalia
# Processing Record 22 of Set 5 | la seyne-sur-mer
# Processing Record 23 of Set 5 | bengkulu
# Processing Record 24 of Set 5 | college
# Processing Record 25 of Set 5 | lazaro cardenas
# Processing Record 26 of Set 5 | sibolga
# Processing Record 27 of Set 5 | fairlie
# Processing Record 28 of Set 5 | qinzhou
# Processing Record 29 of Set 5 | port keats
# Processing Record 30 of Set 5 | bowen
# Processing Record 31 of Set 5 | santa cruz
# Processing Record 32 of Set 5 | verin
# Processing Record 33 of Set 5 | atambua
# Processing Record 34 of Set 5 | port-gentil
# Processing Record 35 of Set 5 | jiangkou
# Processing Record 36 of Set 5 | kapchorwa
# Processing Record 37 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 5 | esik
# Processing Record 39 of Set 5 | dingle
# Processing Record 40 of Set 5 | muros
# Processing Record 41 of Set 5 | plouzane
# Processing Record 42 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 5 | kavieng
# Processing Record 44 of Set 5 | aykhal
# Processing Record 45 of Set 5 | sakaiminato
# Processing Record 46 of Set 5 | komsomolskiy
# Processing Record 47 of Set 5 | ilulissat
# Processing Record 48 of Set 5 | ca mau
# Processing Record 49 of Set 5 | pistsovo
# Processing Record 50 of Set 5 | dauphin
# Processing Record 1 of Set 6 | coquimbo
# Processing Record 2 of Set 6 | antofagasta
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | skjervoy
# Processing Record 5 of Set 6 | ponta delgada
# Processing Record 6 of Set 6 | vangaindrano
# Processing Record 7 of Set 6 | faanui
# Processing Record 8 of Set 6 | charters towers
# Processing Record 9 of Set 6 | avera
# Processing Record 10 of Set 6 | chechat
# Processing Record 11 of Set 6 | virginia beach
# Processing Record 12 of Set 6 | tecoanapa
# Processing Record 13 of Set 6 | margate
# Processing Record 14 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 6 | jinchang
# Processing Record 16 of Set 6 | pierre
# Processing Record 17 of Set 6 | namatanai
# Processing Record 18 of Set 6 | beipiao
# Processing Record 19 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 20 of Set 6 | rongcheng
# Processing Record 21 of Set 6 | fukue
# Processing Record 22 of Set 6 | lasa
# Processing Record 23 of Set 6 | iquique
# Processing Record 24 of Set 6 | kattivakkam
# Processing Record 25 of Set 6 | san andres
# Processing Record 26 of Set 6 | pedana
# Processing Record 27 of Set 6 | san juan del sur
# Processing Record 28 of Set 6 | sao joao da barra
# Processing Record 29 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 6 | hurricane
# Processing Record 31 of Set 6 | yar-sale
# Processing Record 32 of Set 6 | svetlyy
# Processing Record 33 of Set 6 | rafaela
# Processing Record 34 of Set 6 | tetiz
# Processing Record 35 of Set 6 | knysna
# Processing Record 36 of Set 6 | la ronge
# Processing Record 37 of Set 6 | ambikapur
# Processing Record 38 of Set 6 | gondanglegi
# Processing Record 39 of Set 6 | alta floresta
# Processing Record 40 of Set 6 | morant bay
# Processing Record 41 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 42 of Set 6 | sorland
# Processing Record 43 of Set 6 | bandarbeyla
# Processing Record 44 of Set 6 | longyearbyen
# Processing Record 45 of Set 6 | berlevag
# Processing Record 46 of Set 6 | jalu
# Processing Record 47 of Set 6 | anadyr
# Processing Record 48 of Set 6 | manacapuru
# Processing Record 49 of Set 6 | acajutla
# Processing Record 50 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 1 of Set 7 | sao jose da coroa grande
# Processing Record 2 of Set 7 | lagunas
# Processing Record 3 of Set 7 | murdochville
# Processing Record 4 of Set 7 | blind river
# Processing Record 5 of Set 7 | tharad
# Processing Record 6 of Set 7 | ahipara
# Processing Record 7 of Set 7 | tawau
# Processing Record 8 of Set 7 | omsukchan
# Processing Record 9 of Set 7 | ust-shonosha
# Processing Record 10 of Set 7 | castro
# Processing Record 11 of Set 7 | isangel
# Processing Record 12 of Set 7 | te anau
# Processing Record 13 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 7 | szczecin
# Processing Record 15 of Set 7 | agva
# City not found. Skipping...
# Processing Record 16 of Set 7 | brae
# Processing Record 17 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 7 | sola
# Processing Record 20 of Set 7 | road town
# Processing Record 21 of Set 7 | lorengau
# Processing Record 22 of Set 7 | puerto escondido
# Processing Record 23 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 7 | graham
# Processing Record 25 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 26 of Set 7 | luxor
# Processing Record 27 of Set 7 | dhidhdhoo
# Processing Record 28 of Set 7 | angoram
# Processing Record 29 of Set 7 | gat
# Processing Record 30 of Set 7 | agadir
# Processing Record 31 of Set 7 | bereda
# Processing Record 32 of Set 7 | gobabis
# Processing Record 33 of Set 7 | fuyang
# Processing Record 34 of Set 7 | kruisfontein
# Processing Record 35 of Set 7 | sorong
# Processing Record 36 of Set 7 | talnakh
# Processing Record 37 of Set 7 | chulym
# Processing Record 38 of Set 7 | bambanglipuro
# Processing Record 39 of Set 7 | roma
# Processing Record 40 of Set 7 | susangerd
# Processing Record 41 of Set 7 | adiake
# Processing Record 42 of Set 7 | domoni
# Processing Record 43 of Set 7 | hutchinson
# Processing Record 44 of Set 7 | celestun
# Processing Record 45 of Set 7 | ternate
# Processing Record 46 of Set 7 | ugoofaaru
# Processing Record 47 of Set 7 | chumikan
# Processing Record 48 of Set 7 | dali
# Processing Record 49 of Set 7 | la union
# Processing Record 50 of Set 7 | codrington
# Processing Record 1 of Set 8 | grindavik
# Processing Record 2 of Set 8 | santa vitoria do palmar
# Processing Record 3 of Set 8 | chikwawa
# Processing Record 4 of Set 8 | aklavik
# Processing Record 5 of Set 8 | santa isabel do rio negro
# Processing Record 6 of Set 8 | lincoln
# Processing Record 7 of Set 8 | arteaga
# Processing Record 8 of Set 8 | lakes entrance
# Processing Record 9 of Set 8 | san ramon de la nueva oran
# Processing Record 10 of Set 8 | chuy
# Processing Record 11 of Set 8 | tiksi
# Processing Record 12 of Set 8 | colares
# Processing Record 13 of Set 8 | honiara
# Processing Record 14 of Set 8 | waddan
# Processing Record 15 of Set 8 | bati
# Processing Record 16 of Set 8 | moyo
# Processing Record 17 of Set 8 | uroteppa
# City not found. Skipping...
# Processing Record 18 of Set 8 | huarmey
# Processing Record 19 of Set 8 | gushikawa
# Processing Record 20 of Set 8 | kozmodemyansk
# Processing Record 21 of Set 8 | marabba
# Processing Record 22 of Set 8 | buta
# Processing Record 23 of Set 8 | joshimath
# Processing Record 24 of Set 8 | san jose
# Processing Record 25 of Set 8 | sibenik
# Processing Record 26 of Set 8 | shemonaikha
# Processing Record 27 of Set 8 | alekseyevka
# Processing Record 28 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 8 | shelburne
# Processing Record 30 of Set 8 | galdar
# Processing Record 31 of Set 8 | hofn
# Processing Record 32 of Set 8 | sena madureira
# Processing Record 33 of Set 8 | praia
# Processing Record 34 of Set 8 | umm kaddadah
# Processing Record 35 of Set 8 | sambava
# Processing Record 36 of Set 8 | mar del plata
# Processing Record 37 of Set 8 | necochea
# Processing Record 38 of Set 8 | darhan
# Processing Record 39 of Set 8 | shenjiamen
# Processing Record 40 of Set 8 | ketchikan
# Processing Record 41 of Set 8 | yulara
# Processing Record 42 of Set 8 | kahului
# Processing Record 43 of Set 8 | uthal
# Processing Record 44 of Set 8 | beaumont
# Processing Record 45 of Set 8 | bac lieu
# Processing Record 46 of Set 8 | chapais
# Processing Record 47 of Set 8 | chokwe
# Processing Record 48 of Set 8 | abulug
# Processing Record 49 of Set 8 | cidreira
# Processing Record 50 of Set 8 | clervaux
# Processing Record 1 of Set 9 | wiang sa
# Processing Record 2 of Set 9 | qui nhon
# Processing Record 3 of Set 9 | tazovskiy
# Processing Record 4 of Set 9 | soledade
# Processing Record 5 of Set 9 | carutapera
# Processing Record 6 of Set 9 | presidencia roque saenz pena
# Processing Record 7 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 9 | malinta
# Processing Record 9 of Set 9 | shimoda
# Processing Record 10 of Set 9 | vardo
# Processing Record 11 of Set 9 | mount gambier
# Processing Record 12 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 9 | balkanabat
# Processing Record 14 of Set 9 | samarai
# Processing Record 15 of Set 9 | bajil
# Processing Record 16 of Set 9 | padang
# Processing Record 17 of Set 9 | port hedland
# Processing Record 18 of Set 9 | hyeres
# Processing Record 19 of Set 9 | pisco
# Processing Record 20 of Set 9 | zaranj
# Processing Record 21 of Set 9 | mareeba
# Processing Record 22 of Set 9 | gedo
# Processing Record 23 of Set 9 | vestmannaeyjar
# Processing Record 24 of Set 9 | qobustan
# Processing Record 25 of Set 9 | kloulklubed
# Processing Record 26 of Set 9 | tatarskaya pishlya
# Processing Record 27 of Set 9 | rawson
# Processing Record 28 of Set 9 | tessalit
# Processing Record 29 of Set 9 | atar
# Processing Record 30 of Set 9 | astipalaia
# City not found. Skipping...
# Processing Record 31 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 32 of Set 9 | marawi
# Processing Record 33 of Set 9 | yarim
# Processing Record 34 of Set 9 | plettenberg bay
# Processing Record 35 of Set 9 | makasar
# Processing Record 36 of Set 9 | chapada dos guimaraes
# Processing Record 37 of Set 9 | barabinsk
# Processing Record 38 of Set 9 | vila franca do campo
# Processing Record 39 of Set 9 | ko samui
# Processing Record 40 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 41 of Set 9 | bilibino
# Processing Record 42 of Set 9 | buchanan
# Processing Record 43 of Set 9 | homer
# Processing Record 44 of Set 9 | caravelas
# Processing Record 45 of Set 9 | sasykoli
# Processing Record 46 of Set 9 | kapoeta
# Processing Record 47 of Set 9 | medicine hat
# Processing Record 48 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 9 | sungaipenuh
# Processing Record 50 of Set 9 | jacqueville
# Processing Record 1 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 10 | hamilton
# Processing Record 3 of Set 10 | srednekolymsk
# Processing Record 4 of Set 10 | husavik
# Processing Record 5 of Set 10 | tougue
# Processing Record 6 of Set 10 | zelenoborsk
# Processing Record 7 of Set 10 | coolum beach
# Processing Record 8 of Set 10 | mattru
# Processing Record 9 of Set 10 | itarema
# Processing Record 10 of Set 10 | benguela
# Processing Record 11 of Set 10 | cortland
# Processing Record 12 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 10 | katangli
# Processing Record 14 of Set 10 | chara
# Processing Record 15 of Set 10 | gazojak
# Processing Record 16 of Set 10 | pangai
# Processing Record 17 of Set 10 | boone
# Processing Record 18 of Set 10 | gewane
# Processing Record 19 of Set 10 | oyama
# Processing Record 20 of Set 10 | san policarpo
# Processing Record 21 of Set 10 | westport
# Processing Record 22 of Set 10 | tarakan
# Processing Record 23 of Set 10 | ishinomaki
# Processing Record 24 of Set 10 | ayagoz
# Processing Record 25 of Set 10 | umm lajj
# Processing Record 26 of Set 10 | bloemfontein
# Processing Record 27 of Set 10 | saldanha
# Processing Record 28 of Set 10 | flin flon
# Processing Record 29 of Set 10 | bunda
# Processing Record 30 of Set 10 | nizhneangarsk
# Processing Record 31 of Set 10 | palmer
# Processing Record 32 of Set 10 | port elizabeth
# Processing Record 33 of Set 10 | zhanaozen
# Processing Record 34 of Set 10 | bon accord
# Processing Record 35 of Set 10 | salto
# Processing Record 36 of Set 10 | madimba
# Processing Record 37 of Set 10 | tarko-sale
# Processing Record 38 of Set 10 | coihaique
# Processing Record 39 of Set 10 | keelung
# Processing Record 40 of Set 10 | along
# Processing Record 41 of Set 10 | shaowu
# Processing Record 42 of Set 10 | kununurra
# Processing Record 43 of Set 10 | urfa
# City not found. Skipping...
# Processing Record 44 of Set 10 | pemba
# Processing Record 45 of Set 10 | fairbanks
# Processing Record 46 of Set 10 | banjar
# Processing Record 47 of Set 10 | los llanos de aridane
# Processing Record 48 of Set 10 | doctor arroyo
# Processing Record 49 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 50 of Set 10 | goderich
# Processing Record 1 of Set 11 | agutaya
# Processing Record 2 of Set 11 | semey
# Processing Record 3 of Set 11 | kyabe
# Processing Record 4 of Set 11 | hokitika
# Processing Record 5 of Set 11 | khandbari
# Processing Record 6 of Set 11 | morondava
# Processing Record 7 of Set 11 | portland
# Processing Record 8 of Set 11 | maumere
# Processing Record 9 of Set 11 | paamiut
# Processing Record 10 of Set 11 | bagdarin
# Processing Record 11 of Set 11 | arrecife
# Processing Record 12 of Set 11 | sukabumi
# Processing Record 13 of Set 11 | catuday
# Processing Record 14 of Set 11 | makhalino
# Processing Record 15 of Set 11 | kalmunai
# Processing Record 16 of Set 11 | grand gaube
# Processing Record 17 of Set 11 | yaan
# Processing Record 18 of Set 11 | asfi
# Processing Record 19 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 11 | mindif
# Processing Record 21 of Set 11 | qasigiannguit
# Processing Record 22 of Set 11 | mercedes
# Processing Record 23 of Set 11 | cuauhtemoc
# Processing Record 24 of Set 11 | palauig
# Processing Record 25 of Set 11 | teguldet
# Processing Record 26 of Set 11 | businga
# Processing Record 27 of Set 11 | moerai
# Processing Record 28 of Set 11 | mahibadhoo
# Processing Record 29 of Set 11 | acapulco
# Processing Record 30 of Set 11 | qaqortoq
# Processing Record 31 of Set 11 | xapuri
# Processing Record 32 of Set 11 | boguchany
# Processing Record 33 of Set 11 | boca do acre
# Processing Record 34 of Set 11 | ambulu
# Processing Record 35 of Set 11 | rosarito
# Processing Record 36 of Set 11 | chiknayakanhalli
# Processing Record 37 of Set 11 | sabibah
# City not found. Skipping...
# Processing Record 38 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 39 of Set 11 | camacha
# Processing Record 40 of Set 11 | quatre cocos
# Processing Record 41 of Set 11 | makokou
# Processing Record 42 of Set 11 | aktash
# Processing Record 43 of Set 11 | bubaque
# Processing Record 44 of Set 11 | manokwari
# Processing Record 45 of Set 11 | vondrozo
# Processing Record 46 of Set 11 | cosolapa
# Processing Record 47 of Set 11 | mtinko
# Processing Record 48 of Set 11 | valdivia
# Processing Record 49 of Set 11 | pochutla
# Processing Record 50 of Set 11 | dolores
# Processing Record 1 of Set 12 | sakakah
# Processing Record 2 of Set 12 | ancud
# Processing Record 3 of Set 12 | grand-lahou
# Processing Record 4 of Set 12 | nipawin
# Processing Record 5 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 6 of Set 12 | salalah
# Processing Record 7 of Set 12 | tekkali
# Processing Record 8 of Set 12 | ust-nera
# Processing Record 9 of Set 12 | osoyoos
# Processing Record 10 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 11 of Set 12 | tiznit
# Processing Record 12 of Set 12 | beni
# Processing Record 13 of Set 12 | jibuti
# Processing Record 14 of Set 12 | sinnamary
# Processing Record 15 of Set 12 | bathsheba
# Processing Record 16 of Set 12 | hambantota
# Processing Record 17 of Set 12 | filingue
# Processing Record 18 of Set 12 | scottsbluff
# Processing Record 19 of Set 12 | abonnema
# Processing Record 20 of Set 12 | bogotol
# Processing Record 21 of Set 12 | viking
# Processing Record 22 of Set 12 | russell
# Processing Record 23 of Set 12 | novoukrayinka
# Processing Record 24 of Set 12 | the valley
# Processing Record 25 of Set 12 | kermanshah
# Processing Record 26 of Set 12 | upata
# Processing Record 27 of Set 12 | flagstaff
# Processing Record 28 of Set 12 | kurmanayevka
# Processing Record 29 of Set 12 | hiriyur
# Processing Record 30 of Set 12 | iralaya
# Processing Record 31 of Set 12 | eugene
# Processing Record 32 of Set 12 | farkhor
# Processing Record 33 of Set 12 | berbera
# Processing Record 34 of Set 12 | pimentel
# Processing Record 35 of Set 12 | waingapu
# Processing Record 36 of Set 12 | leshukonskoye
# Processing Record 37 of Set 12 | sistranda
# Processing Record 38 of Set 12 | oksfjord
# Processing Record 39 of Set 12 | evensk
# Processing Record 40 of Set 12 | weyburn
# Processing Record 41 of Set 12 | prachuap khiri khan
# Processing Record 42 of Set 12 | lata
# Processing Record 43 of Set 12 | balagansk
# Processing Record 44 of Set 12 | ha giang
# Processing Record 45 of Set 12 | christchurch
# Processing Record 46 of Set 12 | cavalcante
# Processing Record 47 of Set 12 | surt
# Processing Record 48 of Set 12 | araguatins
# City not found. Skipping...
# Processing Record 49 of Set 12 | berezovyy
# Processing Record 50 of Set 12 | xai-xai
# Processing Record 1 of Set 13 | dharmadam
# Processing Record 2 of Set 13 | blonduos
# City not found. Skipping...
# Processing Record 3 of Set 13 | kupang
# Processing Record 4 of Set 13 | dimitrovgrad
# Processing Record 5 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 13 | urubicha
# Processing Record 7 of Set 13 | callaway
# Processing Record 8 of Set 13 | paragominas
# Processing Record 9 of Set 13 | tautira
# Processing Record 10 of Set 13 | murwillumbah
# Processing Record 11 of Set 13 | dunedin
# Processing Record 12 of Set 13 | katherine
# Processing Record 13 of Set 13 | alofi
# Processing Record 14 of Set 13 | mago
# Processing Record 15 of Set 13 | amapa
# Processing Record 16 of Set 13 | mlonggo
# Processing Record 17 of Set 13 | arman
# Processing Record 18 of Set 13 | gilgit
# Processing Record 19 of Set 13 | terney
# Processing Record 20 of Set 13 | yumen
# Processing Record 21 of Set 13 | villazon
# Processing Record 22 of Set 13 | maltahohe
# Processing Record 23 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 13 | sisimiut
# Processing Record 25 of Set 13 | turtkul
# City not found. Skipping...
# Processing Record 26 of Set 13 | kutum
# Processing Record 27 of Set 13 | sande
# Processing Record 28 of Set 13 | savannah bight
# Processing Record 29 of Set 13 | maniitsoq
# Processing Record 30 of Set 13 | kourou
# Processing Record 31 of Set 13 | chicama
# Processing Record 32 of Set 13 | guatire
# Processing Record 33 of Set 13 | sabang
# Processing Record 34 of Set 13 | curillo
# Processing Record 35 of Set 13 | chake chake
# Processing Record 36 of Set 13 | bhainsa
# Processing Record 37 of Set 13 | turukhansk
# Processing Record 38 of Set 13 | hargeysa
# Processing Record 39 of Set 13 | gizo
# Processing Record 40 of Set 13 | bertoua
# Processing Record 41 of Set 13 | abha
# Processing Record 42 of Set 13 | berdigestyakh
# Processing Record 43 of Set 13 | puerto madryn
# Processing Record 44 of Set 13 | nefteyugansk
# Processing Record 45 of Set 13 | esso
# Processing Record 46 of Set 13 | scutelnici
# Processing Record 47 of Set 13 | kaeo
# Processing Record 48 of Set 13 | jizan
# Processing Record 49 of Set 13 | tefe
# Processing Record 50 of Set 13 | manaul
# Processing Record 1 of Set 14 | makakilo city
# Processing Record 2 of Set 14 | camalu
# Processing Record 3 of Set 14 | laiagam
# City not found. Skipping...
# Processing Record 4 of Set 14 | teknaf
# Processing Record 5 of Set 14 | popondetta
# Processing Record 6 of Set 14 | isla mujeres
# Processing Record 7 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 14 | chino valley
# Processing Record 9 of Set 14 | gouyave
# Processing Record 10 of Set 14 | murindo
# Processing Record 11 of Set 14 | araouane
# Processing Record 12 of Set 14 | bustamante
# Processing Record 13 of Set 14 | trincomalee
# Processing Record 14 of Set 14 | inhambane
# Processing Record 15 of Set 14 | tabou
# Processing Record 16 of Set 14 | lucapa
# Processing Record 17 of Set 14 | asau
# Processing Record 18 of Set 14 | jacareacanga
# Processing Record 19 of Set 14 | camana
# Processing Record 20 of Set 14 | bianzhuang
# Processing Record 21 of Set 14 | xinyu
# Processing Record 22 of Set 14 | pingliang
# Processing Record 23 of Set 14 | at-bashi
# Processing Record 24 of Set 14 | yeppoon
# Processing Record 25 of Set 14 | ankola
# Processing Record 26 of Set 14 | mackay
# Processing Record 27 of Set 14 | tabuk
# Processing Record 28 of Set 14 | polohy
# Processing Record 29 of Set 14 | hobyo
# Processing Record 30 of Set 14 | karwar
# Processing Record 31 of Set 14 | port lincoln
# Processing Record 32 of Set 14 | mehamn
# Processing Record 33 of Set 14 | havoysund
# Processing Record 34 of Set 14 | camopi
# Processing Record 35 of Set 14 | bay-khaak
# Processing Record 36 of Set 14 | afanasyevo
# City not found. Skipping...
# Processing Record 37 of Set 14 | novoutkinsk
# Processing Record 38 of Set 14 | marsa matruh
# Processing Record 39 of Set 14 | kasongo-lunda
# Processing Record 40 of Set 14 | vilyuysk
# Processing Record 41 of Set 14 | vereshchagino
# Processing Record 42 of Set 14 | broome
# Processing Record 43 of Set 14 | glace bay
# Processing Record 44 of Set 14 | baihar
# Processing Record 45 of Set 14 | redlands
# Processing Record 46 of Set 14 | burns lake
# Processing Record 47 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 48 of Set 14 | paita
# Processing Record 49 of Set 14 | faro
# Processing Record 50 of Set 14 | zvishavane
# Processing Record 1 of Set 15 | scarborough
# Processing Record 2 of Set 15 | yumbel
# Processing Record 3 of Set 15 | kurilsk
# Processing Record 4 of Set 15 | virden
# Processing Record 5 of Set 15 | nyurba
# Processing Record 6 of Set 15 | mvuma
# Processing Record 7 of Set 15 | saint anthony
# Processing Record 8 of Set 15 | yian
# City not found. Skipping...
# Processing Record 9 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 15 | pacific grove
# Processing Record 11 of Set 15 | chernyanka
# Processing Record 12 of Set 15 | areia branca
# Processing Record 13 of Set 15 | la rioja
# Processing Record 14 of Set 15 | kotovo
# Processing Record 15 of Set 15 | lumsden
# Processing Record 16 of Set 15 | huoqiu
# Processing Record 17 of Set 15 | igarape-miri
# City not found. Skipping...
# Processing Record 18 of Set 15 | guaira
# Processing Record 19 of Set 15 | belmonte
# Processing Record 20 of Set 15 | gazanjyk
# Processing Record 21 of Set 15 | beyneu
# Processing Record 22 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 23 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 24 of Set 15 | fort frances
# Processing Record 25 of Set 15 | vigeland
# Processing Record 26 of Set 15 | kyabram
# Processing Record 27 of Set 15 | bouna
# Processing Record 28 of Set 15 | fallon
# Processing Record 29 of Set 15 | pell city
# Processing Record 30 of Set 15 | port hardy
# Processing Record 31 of Set 15 | port augusta
# Processing Record 32 of Set 15 | judaberg
# Processing Record 33 of Set 15 | aranos
# Processing Record 34 of Set 15 | lalomanu
# City not found. Skipping...
# Processing Record 35 of Set 15 | lerwick
# Processing Record 36 of Set 15 | chauk
# Processing Record 37 of Set 15 | hasaki
# Processing Record 38 of Set 15 | nouadhibou
# Processing Record 39 of Set 15 | kedrovyy
# Processing Record 40 of Set 15 | reconquista
# Processing Record 41 of Set 15 | zhangjiakou
# Processing Record 42 of Set 15 | sidney
# Processing Record 43 of Set 15 | garwa
# Processing Record 44 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 45 of Set 15 | kuytun
# Processing Record 46 of Set 15 | caernarfon
# Processing Record 47 of Set 15 | hualmay
# Processing Record 48 of Set 15 | lake city
# Processing Record 49 of Set 15 | genhe
# Processing Record 50 of Set 15 | cozumel
# Processing Record 1 of Set 16 | yichang
# Processing Record 2 of Set 16 | gravelbourg
# Processing Record 3 of Set 16 | tucurui
# Processing Record 4 of Set 16 | komatipoort
# Processing Record 5 of Set 16 | launceston
# Processing Record 6 of Set 16 | wamba
# Processing Record 7 of Set 16 | uzumlu
# City not found. Skipping...
# Processing Record 8 of Set 16 | buala
# Processing Record 9 of Set 16 | kota belud
# Processing Record 10 of Set 16 | saint simons
# Processing Record 11 of Set 16 | oranjemund
# Processing Record 12 of Set 16 | rexburg
# Processing Record 13 of Set 16 | warmbad
# Processing Record 14 of Set 16 | otane
# Processing Record 15 of Set 16 | nishihara
# Processing Record 16 of Set 16 | khani
# Processing Record 17 of Set 16 | saint-joseph
# Processing Record 18 of Set 16 | vestmanna
# Processing Record 19 of Set 16 | requena
# Processing Record 20 of Set 16 | roebourne
# Processing Record 21 of Set 16 | riyadh
# Processing Record 22 of Set 16 | boyolangu
# Processing Record 23 of Set 16 | kozhva
# Processing Record 24 of Set 16 | tibati
# Processing Record 25 of Set 16 | altay
# Processing Record 26 of Set 16 | ukwa
# Processing Record 27 of Set 16 | lyaskelya
# Processing Record 28 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 16 | lapithos
# Processing Record 30 of Set 16 | terrace
# Processing Record 31 of Set 16 | rafai
# Processing Record 32 of Set 16 | malkangiri
# Processing Record 33 of Set 16 | tulum
# Processing Record 34 of Set 16 | emba
# Processing Record 35 of Set 16 | rorvik
# Processing Record 36 of Set 16 | gualaquiza
# Processing Record 37 of Set 16 | akyab
# Processing Record 38 of Set 16 | kavaratti
# Processing Record 39 of Set 16 | narasannapeta
# Processing Record 40 of Set 16 | santa cruz del norte
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
