# %%
#dependencies 
import numpy as np
from citipy import citipy
import time
import requests
#import the api key
from config import weather_api_key

# %%
#calculating random lat longs
lats = np.random.uniform(low=-90.000, high=90.000, size=100)
longs = np.random.uniform(low=-180.000, high=180.000, size=100)
lat_longs = zip(lats, longs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_longs)

# %%
# create a list for holding the cities.
cities = []
#identify the nearest city for each lat long combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    #if the city is unique then we will at it to the cities list.
    if city not in cities:
        cities.append(city)
#Print the city count to confirm sufficient count.
len(cities)
# Out:
# 83

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# create an empty list to hold weather data
city_data = []
#print the beginning of the loging.
print("Beginning Data Retrieval    ")
print("----------------------------")

#create counter
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | kapaa
# City not found. Skipping...
# Processing Record 2 of Set 1 | jamestown
# City not found. Skipping...
# Processing Record 3 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 4 of Set 1 | vaini
# City not found. Skipping...
# Processing Record 5 of Set 1 | yerbogachen
# City not found. Skipping...
# Processing Record 6 of Set 1 | provideniya
# City not found. Skipping...
# Processing Record 7 of Set 1 | butaritari
# City not found. Skipping...
# Processing Record 8 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 9 of Set 1 | arraial do cabo
# City not found. Skipping...
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | bonthe
# City not found. Skipping...
# Processing Record 12 of Set 1 | broken hill
# City not found. Skipping...
# Processing Record 13 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 14 of Set 1 | tabou
# City not found. Skipping...
# Processing Record 15 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 16 of Set 1 | mahebourg
# City not found. Skipping...
# Processing Record 17 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 18 of Set 1 | kununurra
# City not found. Skipping...
# Processing Record 19 of Set 1 | kirakira
# City not found. Skipping...
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | tasiilaq
# City not found. Skipping...
# Processing Record 22 of Set 1 | turtkul
# City not found. Skipping...
# Processing Record 23 of Set 1 | cabo san lucas
# City not found. Skipping...
# Processing Record 24 of Set 1 | coihaique
# City not found. Skipping...
# Processing Record 25 of Set 1 | inuvik
# City not found. Skipping...
# Processing Record 26 of Set 1 | mafinga
# City not found. Skipping...
# Processing Record 27 of Set 1 | severo-kurilsk
# City not found. Skipping...
# Processing Record 28 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 29 of Set 1 | mayumba
# City not found. Skipping...
# Processing Record 30 of Set 1 | pangnirtung
# City not found. Skipping...
# Processing Record 31 of Set 1 | mitsuke
# City not found. Skipping...
# Processing Record 32 of Set 1 | albany
# City not found. Skipping...
# Processing Record 33 of Set 1 | iquique
# City not found. Skipping...
# Processing Record 34 of Set 1 | valdivia
# City not found. Skipping...
# Processing Record 35 of Set 1 | iqaluit
# City not found. Skipping...
# Processing Record 36 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 37 of Set 1 | lamont
# City not found. Skipping...
# Processing Record 38 of Set 1 | lebu
# City not found. Skipping...
# Processing Record 39 of Set 1 | lukiv
# City not found. Skipping...
# Processing Record 40 of Set 1 | villa oliva
# City not found. Skipping...
# Processing Record 41 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record